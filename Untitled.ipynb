# %%
import pandas as pd 
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

import numpy as np
import pandas as pd
import datetime as dt

import json

# %%
city_list = pd.read_csv("Resources/uscities.csv", encoding="utf-8")
city_list.reset_index()
# Out:
#        index         city   city_ascii state_id  state_name  county_fips  \
# 0          0     New York     New York       NY    New York        36061
# 1          1  Los Angeles  Los Angeles       CA  California         6037
# 2          2      Chicago      Chicago       IL    Illinois        17031
# 3          3        Miami        Miami       FL     Florida        12086
# 4          4       Dallas       Dallas       TX       Texas        48113
# ...      ...          ...          ...      ...         ...          ...
# 28333  28333        Gross        Gross       NE    Nebraska        31015
# 28334  28334       Lotsee       Lotsee       OK    Oklahoma        40143
# 28335  28335    The Ranch    The Ranch       MN   Minnesota        27087
# 28336  28336     Shamrock     Shamrock       OK    Oklahoma        40037
# 28337  28337       Monowi       Monowi       NE    Nebraska        31015
#
#        county_name      lat       lng  population  density   source  military  \
# ...

# %%
growing_city_list = pd.read_csv("Resources/most_populated_cities.csv", encoding="utf-8")
growing_city_list.reset_index()
growing_city_list = growing_city_list.rename(columns={"name":"city", "state":"state_name"})

# %%
city_df = city_list.merge(growing_city_list, how = 'inner', right_on = ['city','state_name'], left_on = ['city','state_id'])
city_df
# Out:
#             city    city_ascii state_id    state_name_x  county_fips  \
# 0          Miami         Miami       FL         Florida        12086
# 1        Phoenix       Phoenix       AZ         Arizona         4013
# 2        Seattle       Seattle       WA      Washington        53033
# 3      San Diego     San Diego       CA      California         6073
# 4         Denver        Denver       CO        Colorado         8031
# 5    San Antonio   San Antonio       TX           Texas        48029
# 6         Austin        Austin       TX           Texas        48453
# 7      Charlotte     Charlotte       NC  North Carolina        37119
# 8   Jacksonville  Jacksonville       FL         Florida        12031
# 9        Raleigh       Raleigh       NC  North Carolina        37183
# 10    Fort Worth    Fort Worth       TX           Texas        48439
# 11         Omaha         Omaha       NE        Nebraska        31055
# 12          Mesa          Mesa       AZ         Arizona         4013
# ...

# %%
database_path = "Resources/Census_Data.sqlite"

engine = create_engine(f"sqlite:///{database_path}")
con = engine.connect()

# %%
connection_string = 'postgresql://user:[redacted]@[compose db host]:10187/compose'

import json  
import sqlalchemy  
db = sqlalchemy.create_engine(connection_string)  
engine = db.connect()  
meta = sqlalchemy.MetaData(engine)

# %%
pd.DataFrame.to_sql()


city_df
city_df.to_sql('cities', con = con, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gr/g0lzn1p15gqfb11105yyt_tm0000gn/T/ipykernel_11139/2504347168.py in <module>
# ----> 1 pd.DataFrame.to_sql()
#       2
#       3
#       4 city_df
#       5 city_df.to_sql('cities', con = con, if_exists = 'append', index = False)
#
# TypeError: to_sql() missing 3 required positional arguments: 'self', 'name', and 'con'
